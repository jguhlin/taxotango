# %%
import plotly.express as px
import polars as pl
import pandas as pd
import numpy as np

# %%
loss = pl.read_csv("../loss_history.txt", separator="\t", has_header=False, new_columns=["Epoch", "Loss", "MARE", "Learning Rate"])
px.line(loss, x="Epoch", y=["Loss", "MARE", "Learning Rate"], title="Loss vs Epoch").show()
